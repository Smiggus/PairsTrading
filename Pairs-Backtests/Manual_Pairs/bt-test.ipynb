# %%
import pairbacktest as pbt

# %%
stock1 = "SPY"
stock2 = "TLT"
start  = '2012-01-01'
end    = '2023-01-01'

StratRet = pbt.backtest_pairs_trading(stock1, stock2, start, end)
StratRet
# Out:
# [*********************100%%**********************]  2 of 2 completed
# c:\Users\MP\OneDrive\CASE\Projects\Financial_Analysis\PairsTrading\Pairs-Backtests\pairbacktest.py:51: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   data['positions'] = data['positions'].replace(to_replace=0, method='ffill')
# Final cumulative return: 127.16%
# Ticker             SPY        TLT  longs  shorts  exits  positions   returns  \
# Date
# 2012-01-03  101.729179  87.432144  False   False  False          0       NaN
# 2012-01-04  101.888710  86.392593  False   False  False          0  0.000000
# 2012-01-05  102.159988  86.238815  False   False  False          0  0.000000
# 2012-01-06  101.896744  86.919693  False   False  False          0 -0.000000
# 2012-01-09  102.144066  86.765961  False   False  False          0  0.000000
# ...                ...        ...    ...     ...    ...        ...       ...
# ...
